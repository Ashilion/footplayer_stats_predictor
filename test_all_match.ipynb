# %%
import utils
loaded_teams = utils.load_teams_from_json("teams.json")
# Out:
# Loaded teams from JSON: [{'code': '18bb7c10', 'name': 'Arsenal'}, {'code': 'b8fd03ef', 'name': 'Manchester-City'}, {'code': '8602292d', 'name': 'Aston-Villa'}, {'code': 'cff3d9bb', 'name': 'Chelsea'}, {'code': '47c64c55', 'name': 'Crystal-Palace'}, {'code': '822bd0ba', 'name': 'Liverpool'}, {'code': '8ef52968', 'name': 'Sunderland'}, {'code': '19538871', 'name': 'Manchester-United'}, {'code': 'd3fd31cc', 'name': 'Everton'}, {'code': 'd07537b9', 'name': 'Brighton-and-Hove-Albion'}, {'code': '361ca564', 'name': 'Tottenham-Hotspur'}, {'code': 'b2b47a98', 'name': 'Newcastle-United'}, {'code': 'fd962109', 'name': 'Fulham'}, {'code': 'cd051869', 'name': 'Brentford'}, {'code': '4ba7cbea', 'name': 'Bournemouth'}, {'code': 'e4a775cb', 'name': 'Nottingham-Forest'}, {'code': '5bfb9659', 'name': 'Leeds-United'}, {'code': '7c21e445', 'name': 'West-Ham-United'}, {'code': '943e8050', 'name': 'Burnley'}, {'code': '8cec06e1', 'name': 'Wolverhampton-Wanderers'}]

# %%
df = utils.get_team_match_logs(loaded_teams[0]['code'], loaded_teams[0]['name'], season="2023-2024")
df.head()
# Out:
# Request successful, parsing HTML...
# Table with links extracted:
#          date                                         match_link
# 0  2023-08-06  /en/matches/10e5c045/Arsenal-Manchester-City-A...
# 1  2023-08-12  /en/matches/26a7f90c/Arsenal-Nottingham-Forest...
# 2  2023-08-21  /en/matches/3b5ecd36/Crystal-Palace-Arsenal-Au...
# 3  2023-08-26  /en/matches/d8f8f8ad/Arsenal-Fulham-August-26-...
# 4  2023-09-03  /en/matches/74125d47/Arsenal-Manchester-United...

# %%
df["match_link"][0]
# Out:
# '/en/matches/10e5c045/Arsenal-Manchester-City-August-6-2023-FA-Community-Shield'

# %%
all_matches = utils.get_all_season_match(season="2023-2024")
print(len(all_matches))
all_matches[:5]
# Out:
# Loaded teams from JSON: [{'code': '18bb7c10', 'name': 'Arsenal'}, {'code': 'b8fd03ef', 'name': 'Manchester-City'}, {'code': '8602292d', 'name': 'Aston-Villa'}, {'code': 'cff3d9bb', 'name': 'Chelsea'}, {'code': '47c64c55', 'name': 'Crystal-Palace'}, {'code': '822bd0ba', 'name': 'Liverpool'}, {'code': '8ef52968', 'name': 'Sunderland'}, {'code': '19538871', 'name': 'Manchester-United'}, {'code': 'd3fd31cc', 'name': 'Everton'}, {'code': 'd07537b9', 'name': 'Brighton-and-Hove-Albion'}, {'code': '361ca564', 'name': 'Tottenham-Hotspur'}, {'code': 'b2b47a98', 'name': 'Newcastle-United'}, {'code': 'fd962109', 'name': 'Fulham'}, {'code': 'cd051869', 'name': 'Brentford'}, {'code': '4ba7cbea', 'name': 'Bournemouth'}, {'code': 'e4a775cb', 'name': 'Nottingham-Forest'}, {'code': '5bfb9659', 'name': 'Leeds-United'}, {'code': '7c21e445', 'name': 'West-Ham-United'}, {'code': '943e8050', 'name': 'Burnley'}, {'code': '8cec06e1', 'name': 'Wolverhampton-Wanderers'}]
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# Request successful, parsing HTML...
# Table with links extracted:
# 630
# ['/en/matches/c9ab1f95/Burnley-Brighton-and-Hove-Albion-April-13-2024-Premier-League',
#  '/en/matches/416b23b9/Arsenal-Liverpool-January-7-2024-FA-Cup',
#  '/en/matches/2eca8900/Sheffield-United-Arsenal-March-4-2024-Premier-League',
#  '/en/matches/ad941675/Swansea-City-Bournemouth-August-29-2023-EFL-Cup',
#  '/en/matches/ca1e26a0/Brentford-Liverpool-February-17-2024-Premier-League']
